# %% [markdown]
# # **Submitted by: Musharaf Ahsan**

# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns

# %%
df = pd.read_csv('products.csv');
df.head()
# Out:
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  quantityInStock  buyPrice    MSRP
# 0         1:10           Min Lin Diecast             7933     48.81   95.70
# 1         1:10   Classic Metal Creations             7305     98.58  214.30
# 2         1:10  Highway 66 Mini Classics             6625     68.99  118.94
# 3         1:10         Red Start Diecast             5582     91.02  193.66
# 4         1:10   Motor City Art Classics             3252     85.68  136.00

# %%
sns.barplot(x='productLine', y='quantityInStock', data=df);

# %%
sns.boxplot(x='productName', y='quantityInStock', data=df);

# %%
sns.lineplot(x='productLine', y='buyPrice', data=df);

# %%
sns.boxenplot(x='productLine', y='buyPrice', data=df);

# %%
sns.histplot(df['MSRP']);

# %%
sns.barplot(x='productLine', y='MSRP', data=df);

# %%
sns.histplot(df['quantityInStock']);
