# %% [markdown]
# # **Submitted by: Musharaf Ahsan**

# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns

# %%
df = pd.read_csv('orders.csv');
df
# Out:
#      orderNumber      status  customerNumber
# 0          10100     Shipped             363
# 1          10101     Shipped             128
# 2          10102     Shipped             181
# 3          10103     Shipped             121
# 4          10104     Shipped             141
# ..           ...         ...             ...
# 321        10421  In Process             124
# 322        10422  In Process             157
# 323        10423  In Process             314
# 324        10424  In Process             141
# 325        10425  In Process             119
#
# [326 rows x 3 columns]

# %%
sns.lineplot(x='status', y='orderNumber', data=df);

# %%
sns.boxenplot(df["orderNumber"]);
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x='status', y='orderNumber', data=df);

# %%
sns.boxplot(x='status', y='orderNumber', data=df);

# %%
sns.histplot(df['customerNumber']);
