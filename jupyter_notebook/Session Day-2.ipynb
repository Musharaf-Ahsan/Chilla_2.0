# %% [markdown]
# ##### Notebook No: 3

# %% [markdown]
# # Python ka Chilla
# ## Musharaf Ahsan
# # Chart Suggestions and other Concepts

# %%
# body mass index (BMI)
# input weight in kg
# Height in meters
# calculate BMI
# show output as: My name is _____ and my BMI is_____ .
# weight (kg) / [height (m)]2
name=input("What is your name? ")
height=input("What is your height in meters? ")
height=float(height)
weight=input("Whst is your weight? ")
weight=float(weight)
BMI= weight/height**2
BMI
# Out:
# What is your name? Musharaf
# What is your height in meters? 1.72
# Whst is your weight? 47
# 15.886965927528395

# %%
print("My name is",name, "and my BMI is ", BMI)
# Out:
# My name is Musharaf and my BMI is  15.886965927528395

# %% [markdown]
# ## Types of Plots
# The Abela’s Cheatsheet provides a general overview, which starts with a simple question:What would you like to show?
#
# The answer provides a decision tree to follow and determine the kind of visualization of the data you can use.
# ![image.png](attachment:image.png)

# %% [markdown]
# The four main decision tree branches are based on the purpose of the perfect visualization:

# %% [markdown]
# - Relationship
# - Comparison
# - Distribution
# - Composition

# %% [markdown]
# On each node, the questions focus on the nature of the information (static or dynamic),
#
# the number of variables involved, and the series and categories.

# %% [markdown]
# ## Relationship
# When the purpose of the chart is to show the relationship between variables of data or
#
# to infer some relationship insight, the cheat sheet proposes two charts:

# %% [markdown]
# ### - Scatterplot

# %% [markdown]
# - For analysis of the relationship b can be detected-throughclustering techniquesetween two variables, the suggested visualization is a simple scatter plot. Relationships.A scatter plot is a diagram where each value in the data set is represented by a dot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row = "sex", hue="alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()

# %% [markdown]
# ### - Bubble Chart
# - For three variables, a useful and perfect visualization is the bubble chart. In nature, it is similar to the scatter plot, but it also adds the diameter of each point as a samplingvariable. An example of this chat would be the analysis of the relationship between product price, product sales, and the percentage of the total of the whole sales (that would be the diameter).
# - A bubble plot is a scatterplot where the circle size is mapped to the value of a third numeric variable.

# %% [markdown]
# #### Example
# ![image.png](attachment:image.png)

# %% [markdown]
# ## BarPlot  for Categorical Variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x = "sex", y = "survived", hue="class", kind= "bar", data =titanic)
plt.show()

# %% [markdown]
# ## CountPlot for Continous variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
p1=sns.countplot(x = "sex", hue="class", data =titanic)
p1.set_title("Plot for Counting")
plt.show()

# %% [markdown]
# ## Data_set of Titanic

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
p1=sns.countplot(x = "who", hue="alone", data =titanic)
p1.set_title("Plot for Counting")
plt.show()

# %% [markdown]
# ## Step involved in Data Visualization

# %%
# Step 1: Import LIbraries
import seaborn as sns
import matplotlib.pyplot as plt
# Step 2: Set a Theme
sns.set_theme(style="ticks", color_codes=True)
# Step 3: Import data set you can also import your own data set.
titanic = sns.load_dataset("titanic")
# Step 4: Plot Basic graph
p1=sns.countplot(x = "sex", data =titanic)
# Step 5: Give any Title to your Graph
p1.set_title("Plot for Counting with one Variable")
plt.show()

p1=sns.countplot(x = "sex", hue="class", data =titanic)
# Step 5: Give any Title to your Graph
p1.set_title("Plot for Counting with two Variable")
plt.show()

# %% [markdown]
# ### More about plots
# https://www.techprevue.com/decision-tree-perfect-visualisation-data/
